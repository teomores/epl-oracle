# %%
import pandas as pd
cl = pd.read_csv('../dataset/premier/transformed/transformed_premier_1415_2.csv')
cl['league_year']=2018
cl.head()
# Out:
#    match_date match_hour  match_round       home_team   away_team  home_goals  \
# 0  24.05.2015      16:00           38         Arsenal   West Brom           4
# 1  24.05.2015      16:00           38     Aston Villa     Burnley           0
# 2  24.05.2015      16:00           38         Chelsea  Sunderland           3
# 3  24.05.2015      16:00           38  Crystal Palace     Swansea           1
# 4  24.05.2015      16:00           38         Everton   Tottenham           0
#
#    away_goals  10bet_1  10bet_X  10bet_2  ...  william hill_opening_1  \
# 0           1     1.33     5.45     8.50  ...                    1.33
# 1           1     2.15     3.40     3.35  ...                    2.05
# 2           1     1.28     5.70    10.25  ...                    1.40
# 3           0     1.77     3.75     4.65  ...                    2.25
# 4           1     2.25     3.50     3.05  ...                    2.40
#
#    william hill_opening_X  william hill_opening_2  youwin_1  youwin_X  \
# ...

# %%
sorted(set(cl.home_team))
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Hull',
#  'Leicester',
#  'Liverpool',
#  'Manchester City',
#  'Manchester Utd',
#  'Newcastle',
#  'QPR',
#  'Southampton',
#  'Stoke',
#  'Sunderland',
#  'Swansea',
#  'Tottenham',
#  'West Brom',
#  'West Ham']

# %%
cl.to_csv('transformed_premier_1819_2.csv', index=False)
