# %%
import pandas as pd
odds_df = pd.read_csv('../dataset/premier/lightgbm/lightgbm_base_odds_premier.csv')
odds_df = odds_df.sort_values(by=['match_year','match_month','match_day','match_hour','match_round','home_team','away_team']).reset_index(drop=True)
odds_df.head()
# Out:
#    10bet_1  10bet_2  10bet_X  10bet_opening_1  10bet_opening_2  \
# 0     1.12    20.70     7.96             1.15            21.60
# 1     1.73     5.14     3.49             1.66             5.09
# 2     3.15     2.31     3.27             3.25             2.25
# 3     2.23     3.29     3.26             2.27             3.34
# 4     2.87     2.61     3.12             2.96             2.57
#
#    10bet_opening_X  188bet_1  188bet_2  188bet_X  188bet_opening_1  ...  \
# 0             7.63      1.18     26.00      7.50              1.22  ...
# 1             3.45      1.77      5.30      3.60              1.81  ...
# 2             3.22      3.10      2.36      3.40              3.15  ...
# 3             3.22      2.27      3.40      3.35              2.33  ...
# 4             3.08      2.90      2.60      3.30              2.95  ...
#
#    youwin_1  youwin_2  youwin_X  youwin_opening_1  youwin_opening_2  \
# 0      1.13     17.00      6.00              1.20             13.00
# ...

# %%
bet365 = odds_df[['bet365_1','bet365_X','bet365_2','label','match_day','match_month','match_year','match_hour','match_round']]
bet365.head()
# Out:
#    bet365_1  bet365_X  bet365_2  label  match_day  match_month  match_year  \
# 0      1.20      7.00     21.00      1         15            8        2009
# 1      1.73      3.60      5.00      2         15            8        2009
# 2      3.40      3.20      2.25      2         15            8        2009
# 3      2.29      3.25      3.25      2         15            8        2009
# 4      2.88      3.25      2.50      2         15            8        2009
#
#    match_hour  match_round
# 0          13            1
# 1          16            1
# 2          16            1
# 3          16            1
# 4          16            1

# %%
# baseline che usa solo le quote
subset_bet365 = bet365[(bet365.match_round<34) & (bet365.match_year>2016)].reset_index(drop=True)
result = []
for p1,pX,p2 in zip(subset_bet365['bet365_1'], subset_bet365['bet365_X'], subset_bet365['bet365_2']):
    if min([p1,pX,p2]) == p1: result.append(1)
    elif min([p1,pX,p2]) == pX: result.append(0)
    else: result.append(2)

correct = 0
for ind,true,predicted in zip(subset_bet365.index, subset_bet365.label, result):
    if true == predicted:
        correct+=1
correct*100 / subset_bet365.shape[0]
# Out:
# 58.4788029925187

# %%
# baseline che usa solo le quote
result = []
for p1,pX,p2 in zip(bet365['bet365_1'], bet365['bet365_X'], bet365['bet365_2']):
    if min([p1,pX,p2]) == p1: result.append(1)
    elif min([p1,pX,p2]) == pX: result.append(0)
    else: result.append(2)

correct = 0
for ind,true,predicted in zip(bet365.index, bet365.label, result):
    if true == predicted:
        correct+=1
correct*100 / bet365.shape[0]
# Out:
# 54.71052631578947

# %%
bet365.label.tolist().count(2) / bet365.shape[0]
# Out:
# 0.29

# %%
# predizioni col modello da 60% accuracy
best_preds = [1,1,2,1,1,2,2,2,1,1,1,1,1,2,2,1,1,1,2,1,1,2,0,1,1,1,1,2,1,1,1,2,1,2,1,1,1,1,0,1,2,2,1,1,1,1,1,1,1,2]

# %%
bet365.tail(50)
# Out:
#       bet365_1  bet365_X  bet365_2  label  match_day  match_month  match_year  \
# 3750      2.70      3.20      2.87      1         13            4        2019
# 3751      1.33      5.75      9.50      1         13            4        2019
# 3752     13.00      6.75      1.25      2         14            4        2019
# 3753      1.72      3.90      5.25      1         14            4        2019
# 3754      3.70      3.70      2.05      2         15            4        2019
# 3755      2.00      3.30      4.50      2         16            4        2019
# 3756      1.28      6.50     10.50      1         20            4        2019
# 3757      1.70      4.33      4.75      2         20            4        2019
# 3758      4.20      3.60      1.95      2         20            4        2019
# 3759      3.20      3.60      2.30      0         20            4        2019
# 3760      1.95      3.20      5.00      0         20            4        2019
# ...

# %%
correct = 0
for true,predicted in zip(bet365.tail(50).label, best_preds):
    if true == predicted:
        correct+=1
correct
# Out:
# 25
